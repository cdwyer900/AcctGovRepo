# %%
import spacy
import spacy_cleaner
from spacy_cleaner.processing import removers, replacers, mutators
from spacy.tokens import Doc
import re

model = spacy.load("en_core_web_lg")
pipeline = spacy_cleaner.Pipeline(
    model,
    removers.remove_url_token,
    #removers.remove_stopword_token,
    #removers.remove_punctuation_token,
    #replacers.replace_punctuation_token,
    #mutators.mutate_lemma_token,
)

infile = open("VISA-ESG-txt-spacy.txt","r")
text = infile.read()
#remove \n from file
text = re.sub('\n','',text)
text = re.sub('\t','',text)
text = re.sub('•','',text)
text = re.sub('|','',text)

#text = re.sub(r'\W+','',text)

#convert text into a list
listText = list(text.split(" "))

listText = list(filter(None, listText))
#listText = [i for i in listText if i]


result = pipeline.clean(listText)
result2 = []
for t in result:
    if t !='':
        result2.append(t.lower())
# Out:
# Cleaning Progress: 100%|████████████████| 22852/22852 [00:08<00:00, 2550.34it/s]

# %%
#dir(removers)
#dir(spacy_cleaner)
#help(spacy_cleaner.Pipeline)
#help(removers.transformers)

# %%
#create nlp object
nlp = spacy.load('en_core_web_lg')
# turn result2 list into a str
result2str = ' '.join(result2)
doc = nlp(result2str)

# %%
for token in doc:
#  if token.text.startswith("artificial"):
#    print(token.text, token.has_vector, token.vector_norm, token.is_oov)
#  if token.is_oov:
#    print(token.text, token.pos_, token.tag_)
#  if token.tag_ == "NNP":
#    print(token.text, token.pos_, token.tag_)
#  if token.text == "bias":
#    print(token.sent)
#    print()
  #if token.text == "artificial":
  #  print(token.sent)
  #  print()
  if token.text == "internal":
    print(token.text, token.pos_, token.tag_, token.has_vector, token.sentiment)
    #print(token.sent)
    print()
# Out:
# internal ADJ JJ True 0.0
#
# internal ADJ JJ True 0.0
#
# internal ADJ JJ True 0.0
#
# internal ADJ JJ True 0.0
#
# internal ADJ JJ True 0.0
#
# internal ADJ JJ True 0.0
#
# internal ADJ JJ True 0.0
#
# internal ADJ JJ True 0.0
#
# internal ADJ JJ True 0.0
#
# internal ADJ JJ True 0.0
#
# internal ADJ JJ True 0.0
#
# internal ADJ JJ True 0.0

# %%
for token in doc:
#    print(token.text,token.sentiment)
#  if token.text.startswith("artificial"):
#    print(token.text, token.has_vector, token.vector_norm, token.is_oov)
#  if token.is_oov:
#    print(token.text, token.pos_, token.tag_)
#  if token.tag_ == "NNP":
#    print(token.text, token.pos_, token.tag_)
#  if token.text == "bias":
#    print(token.sent)
#    print()
  if token.text == "ai":
    print(token.sent)
    print()
# Out:
# specifically , we have invested approximately $ 9 billion in cybersecurity over the past five years , with about $ 500 million of that specifically allocated to data and artificial intelligence ( ai ) capabilities .
#
# transaction authorization use tools such as visa advanced authorization , which applies real - time ai and machine learning to evaluate the trustworthiness of transactions to prevent fraud without inconveniencing consumers .
#
# visa advanced authorization and visa risk manager used ai and machine learning to help reduce fraud by $ 26b in 2021 .
#
# 2021 environmental , social & governance report | 17 ai - powered innovations for smarter payments visa is leveraging ai to improve our customer experience and enhance processes that enable the movement of billions of dollars across thousands of institutions in more than 200 countries and territories and 160 currencies .
#
# ...

# %%
from collections import Counter

words = [token.text
         for token in doc
         if not token.is_stop and not token.is_punct and token.is_alpha]

# noun tokens that arent stop words or punctuations
nouns = [token.text
         for token in doc
         if (not token.is_stop and
             not token.is_punct and token.is_alpha and
             token.pos_ == "NOUN")]

# five most common tokens
word_freq = Counter(words)
common_words = word_freq.most_common(400)

# five most common noun tokens
noun_freq = Counter(nouns)
common_nouns = noun_freq.most_common(400)

# %%
outfile= open("results.txt","w")
for l in common_words:
    a,b = l
    
    outfile.write(str(a)+","+str(b)+"\n")
    
    
outfile.close()

# %%
"""
#display entities
for ent in doc.ents:
    print(ent)
    #print(ent.text, ent.start_char, ent.end_char, ent.label_)

"""
for ent in doc.ents:
    if ent.label_ == "ORG":
        print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# the united nations sustainable development 240 282 ORG
# communities & economies small & micro 310 347 ORG
# digital equity & 360 376 ORG
# commerce & 420 430 ORG
# tcfd 43 819 826 ORG
# ghg emissions verification statement 1005 1041 ORG
# visa 3103 3107 ORG
# communities & 5613 5626 ORG
# smbs 5644 5648 ORG
# visa advanced authorization 5934 5961 ORG
# visa 6124 6128 ORG
# communities & economies 6968 6991 ORG
# commerce & 7001 7011 ORG
# wef 7762 7765 ORG
# visa 7914 7918 ORG
# visa 8288 8292 ORG
# sec 9528 9531 ORG
# our environmental , social & governance approach visa 11381 11434 ORG
# communities & economies 11849 11872 ORG
# commerce & 11882 11892 ORG
# visa 12271 12275 ORG
# eco forum council for inclusive capitalism 17618 17660 ORG
# the united nations sustainable development 17849 17891 ORG
# the united nations 17898 17916 ORG
# un 17919 17921 ORG
# ftse 19039 19043 ORG
# cpa 19175 19178 ORG
# employers2021 19267 19280 ORG
# forbes world 19283 19295 ORG
# ...

# %%
for token in doc:
    if token.text == "bias":
        print(token.sent)
        print()
# Out:
# responsible use of artificial intelligence ( ai ) bias , or the potential of producing unlawful or undesired discrimination , is one of the greatest risks posed by ai .
#
# bias can enter the product lifecycle at many stages , and visa believes that mitigation needs to exist at all stages .
#
# visa ’s model risk management ( mrm ) tests models for statistical integrity as well as unintended impacts , like bias .
#
# introduced leading and belonging at visa , a new learning experience for leaders , created in partnership with the perception institute , an organization that translates mind science research on race and other identities into solutions that reduce bias and discrimination and promote belonging .
#
# we encourage employees to combat unconscious bias by participating in internal courses on our virtual learning platforms .
#
# ...

# %%
for token in doc:
    if token.text == "board":
        print(token.sent)
        print()
# Out:
# sincerely , alfred f. kelly , jr. chairman and chief executive officer , visa 2021 environmental , social & governance report | 1 fy21 visa esg performance highlights our esg strategy helps us deliver on our purpose : uplift everyone , everywhere by being the best way to pay and be paid empowering people , communities & economies 30.7 m smbs digitally enabled toward 50 million goal by 20231 8.5 k startups from 100 countries in visa everywhere initiative 3.2 m people reached by visa practical money skills – offered in 48 countries and 19 languages securing commerce & protecting customers $ 26b of fraud losses prevented by visa advanced authorization and visa risk manager $ 9b invested over past five years to boost cybersecurity and reduce fraud $ 0.07 historically low fraud rate for every $ 100 transacted on visa ’s network investing in our people equal payamong men and women for the same work 21 k active users in visa learning hub 50 visa black scholars joined inaugural cohort operat
# ...
